# %%
import pandas as pd

bb_music = pd.read_csv("billboard.csv")
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
bb_music.shape
# Out:
# (317, 81)

# %%
bb_music.head(3)
# Out:
#            artiste                     track genre date.entered date.peaked  \
# 0  Destiny's Child  Independent Women Part I  Rock   2000-09-23  2000-11-18
# 1          Santana              Maria, Maria  Rock   2000-02-12  2000-04-08
# 2    Savage Garden        I Knew I Loved You  Rock   1999-10-23  2000-01-29
#
#    x1st.week  x2nd.week  x3rd.week  x4th.week  x5th.week  ...  x67th.week  \
# 0         78       63.0       49.0       33.0       23.0  ...         NaN
# 1         15        8.0        6.0        5.0        2.0  ...         NaN
# 2         71       48.0       43.0       31.0       20.0  ...         NaN
#
#    x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x74th.week  x75th.week  x76th.week
# ...

# %%
bb_music = bb_music.rename (columns={
    'artiste': 'artiste',
    'track' : 'track',
    'genre' : 'genre',
    'date.entered': 'date_entered',
    'date.peaked' : 'date_peaked',
    'x1st.week' : 'first_week',
    'x2nd.week' : 'second_week',
    'x3rd.week' : 'third_week',
    'x4th.week' : 'fourth_week',
    'x5th.week' : 'fifth_week'
    
})

# %%
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date_entered date_peaked  first_week  second_week  third_week  \
# ...

# %%
bb_music = bb_music.loc[:, ['artiste', 'track','genre', 'date_entered', 'date_peaked', 'first_week', 'second_week', 'third_week', 'fourth_week', 'fifth_week']]

# %%
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date_entered date_peaked  first_week  second_week  third_week  \
# ...

# %%
bb_music.shape
# Out:
# (317, 10)

# %%
bb_music.isna().sum()
# Out:
# artiste          0
# track            0
# genre            0
# date_entered     0
# date_peaked      0
# first_week       0
# second_week      5
# third_week      10
# fourth_week     17
# fifth_week      25
# dtype: int64

# %%
bb_music.isna().mean()
# Out:
# artiste         0.000000
# track           0.000000
# genre           0.000000
# date_entered    0.000000
# date_peaked     0.000000
# first_week      0.000000
# second_week     0.015773
# third_week      0.031546
# fourth_week     0.053628
# fifth_week      0.078864
# dtype: float64

# %%
bb_music.dropna(thresh = 4)
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date_entered date_peaked  first_week  second_week  third_week  \
# ...

# %%
bb_music.shape
# Out:
# (317, 10)

# %%
bb_music.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date_entered     object
# date_peaked      object
# first_week        int64
# second_week     float64
# third_week      float64
# fourth_week     float64
# fifth_week      float64
# dtype: object

# %%
bb_music['date_entered'] = pd.to_datetime(bb_music['date_entered'])

# %%
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date_entered date_peaked  first_week  second_week  third_week  \
# ...

# %%
bb_music['date_peaked'] = pd.to_datetime(bb_music['date_peaked'])

# %%
bb_music.dtypes
# Out:
# artiste                 object
# track                   object
# genre                   object
# date_entered    datetime64[ns]
# date_peaked     datetime64[ns]
# first_week               int64
# second_week            float64
# third_week             float64
# fourth_week            float64
# fifth_week             float64
# dtype: object

# %%
week = pd.melt(bb_music, id_vars = ['date_entered', 'date_peaked'], value_vars=['first_week', 'second_week', 'third_week', 'fourth_week', 'fifth_week'],
                  value_name='', var_name='week')

# %%
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date_entered date_peaked  first_week  second_week  third_week  \
# ...

# %%
week.tail()
# Out:
#      date_entered date_peaked        week
# 1580   2000-08-05  2000-08-05  fifth_week NaN
# 1581   2000-02-12  2000-02-12  fifth_week NaN
# 1582   2000-09-02  2000-09-02  fifth_week NaN
# 1583   2000-07-01  2000-07-01  fifth_week NaN
# 1584   2000-10-28  2000-10-28  fifth_week NaN

# %%
week
# Out:
#      date_entered date_peaked        week
# 0      2000-09-23  2000-11-18  first_week  78.0
# 1      2000-02-12  2000-04-08  first_week  15.0
# 2      1999-10-23  2000-01-29  first_week  71.0
# 3      2000-08-12  2000-09-16  first_week  41.0
# 4      2000-08-05  2000-10-14  first_week  57.0
# ...           ...         ...         ...   ...
# 1580   2000-08-05  2000-08-05  fifth_week   NaN
# 1581   2000-02-12  2000-02-12  fifth_week   NaN
# 1582   2000-09-02  2000-09-02  fifth_week   NaN
# 1583   2000-07-01  2000-07-01  fifth_week   NaN
# 1584   2000-10-28  2000-10-28  fifth_week   NaN
#
# [1585 rows x 4 columns]

# %%
bb_music.insert (3, 'entered_to_peak', bb_music['date_peaked'] - bb_music['date_entered'])

# %%
bb_music
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     entered_to_peak date_entered date_peaked  first_week  second_week  \
# ...

# %%
bb_music.dtypes
# Out:
# artiste                     object
# track                       object
# genre                       object
# entered_to_peak    timedelta64[ns]
# date_entered        datetime64[ns]
# date_peaked         datetime64[ns]
# first_week                   int64
# second_week                float64
# third_week                 float64
# fourth_week                float64
# fifth_week                 float64
# dtype: object
